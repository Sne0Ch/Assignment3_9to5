-- %% [markdown]
-- # <span style="font-size: 20pt; font-family: Montserrat, sans-serif; color: rgb(92, 148, 206); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Graded Assignment 3: 9 to 5</span>
--
--
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to show off your SQL skills! For each question, copy the SQL query you used and make note of the answer.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For this assignment, you will be using the Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results which can be found on</span> [<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(17, 85, 204); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; text-decoration-line: underline; vertical-align: baseline; white-space: pre-wrap;">Kaggle</span>](https://www.kaggle.com/bls/employment)<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Business Issue</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">You are working for the Bureau of Labor Statistics with the United States government and have been approached by your boss with an important meeting request. You have been asked by your supervisor to meet with Dolly Parton whose nonprofit is looking to shed light on the state of employment in the United States. As part of the 9 to 5 project, their research is focused on production and nonsupervisory employees and how those employees fare compared to all employees in the United States. While the data the BLS collects from the CES is publicly available, Dolly Parton and her colleagues need your assistance navigating the thousands of rows in each table in LaborStatisticsDB.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">About the Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">This dataset comes directly from the Bureau of Labor Statistics’ Current Employment Survey (CES). Here are some things you need to know:</span>
--
-- 1. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The industry table contains an NAICS code. This is different from the industry code. NAICS stands for North American Industry Classification System.</span>
--
-- 2. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Series ID is composed of multiple different codes. CES stands for Current Employment Survey, the name of the survey which collected the data. The industry code as specified by the BLS and the data type code as specified in the datatype table.</span>
--
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Set Up</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To connect to the database, use the same connection info used during the SQL lessons.&nbsp;</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For the assignment, we will be using the LaborStatisticsDB database.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Database Exploration</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To start with, let’s get to know the database further.</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 10pt; white-space: pre-wrap;">Use this space to make note of each table in the database, the columns within each table, each column’s data type, and how the tables are connected. You can write this down or draw a diagram. Whatever method helps you get an understanding of what is going on with LaborStatisticsDB.</span>

-- %% [markdown]
-- To add a photo, diagram or document to your file, drop the file into the folder that holds this notebook.  Use the the link button to the right of the  \</\> symbol in the gray part of this cell, the link is just the name of your file.

-- %% [markdown]
-- ![](c:\Users\snigd\OneDrive\Desktop\labor_statistics_schema.jpg)

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">What is the datatype for women employees? Data_type_text for 'women employees' is a <b>string </b>- </span> nvarchar(100), data\_type\_code is **integer**.

-- %%
SELECT data_type_text, data_type_code
FROM LaborStatisticsDB.dbo.datatype
WHERE data_type_text =  'women employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.090
-- <table><tr><th>data_type_text</th><th>data_type_code</th></tr><tr><td>WOMEN EMPLOYEES</td><td>10</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the series id for&nbsp; women employees in the commercial banking industry in the financial activities supersector? Series ID: CES5552211010, CEU5552211010</span>

-- %%
SELECT series_id
FROM LaborStatisticsDB.dbo.series
WHERE data_type_code = 10 AND industry_code = '55522110' AND supersector_code = '55'
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.644
-- <table><tr><th>series_id</th></tr><tr><td>CES5552211010</td></tr><tr><td>CEU5552211010</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Join in on the Fun</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to start joining! You can choose the type of join you use, just make sure to make a&nbsp; note!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join&nbsp; annual_2016 with series on series_id. We only want the data in the annual_2016 table to be included in the result.</span>

-- %%
SELECT TOP 5 a.id, a.series_id, a.year, a.period, a.value, a.footnote_codes, a.original_file
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN  LaborStatisticsDB.dbo.series AS b
ON a.series_id = b.series_id
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.174
-- <table><tr><th>id</th><th>series_id</th><th>year</th><th>period</th><th>value</th><th>footnote_codes</th><th>original_file</th></tr><tr><td>0</td><td>CEU5500000007</td><td>2016</td><td>M13</td><td>36.9</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>1</td><td>CEU5500000008</td><td>2016</td><td>M13</td><td>26.11</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>2</td><td>CEU5500000030</td><td>2016</td><td>M13</td><td>962.73</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>3</td><td>CEU5500000031</td><td>2016</td><td>M13</td><td>411.29</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>4</td><td>CEU5500000032</td><td>2016</td><td>M13</td><td>11.15</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and datatype on data_type_code</span>

-- %%
SELECT TOP 5 s.series_id, d.data_type_code 
FROM LaborStatisticsDB.dbo.series as s
INNER JOIN LaborStatisticsDB.dbo.datatype as d 
ON s.data_type_code = d.data_type_code
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.081
-- <table><tr><th>series_id</th><th>data_type_code</th></tr><tr><td>CES0000000001</td><td>1</td></tr><tr><td>CES0000000010</td><td>10</td></tr><tr><td>CES0000000025</td><td>25</td></tr><tr><td>CES0000000026</td><td>26</td></tr><tr><td>CES0500000001</td><td>1</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and industry on industry_code</span>

-- %%
SELECT TOP 5 s.series_id, i.industry_code
FROM LaborStatisticsDB.dbo.series as s
INNER JOIN LaborStatisticsDB.dbo.industry as i 
ON s.industry_code = i.industry_code
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.329
-- <table><tr><th>series_id</th><th>industry_code</th></tr><tr><td>CES0000000001</td><td>0</td></tr><tr><td>CES0000000010</td><td>0</td></tr><tr><td>CES0000000025</td><td>0</td></tr><tr><td>CES0000000026</td><td>0</td></tr><tr><td>CES0500000001</td><td>5000000</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Aggregate Your Friends and Code some SQL</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Put together the following:</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; No chopping people into little bits, please.</span>

-- %%
SELECT ROUND((SUM(a.value)), 0) AS total_employees_all_industries
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE series_title = 'ALL EMPLOYEES'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.101
-- <table><tr><th>total_employees_all_industries</th></tr><tr><td>2340612</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many women employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; Answer : 1125490</span>

-- %%
SELECT ROUND((SUM(a.value)), 0) AS women_employees_all_industries
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE series_title = 'WOMEN EMPLOYEES'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.109
-- <table><tr><th>women_employees_all_industries</th></tr><tr><td>1125490</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many production/nonsupervisory employees were reported in 2016? Round to the nearest whole number.&nbsp;Answer : 1263650</span>

-- %%
SELECT ROUND((SUM(a.value)), 0) AS 'prod/non supervisory employee'
FROM LaborStatisticsDB.dbo.annual_2016 AS a 
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE series_title = 'production and nonsupervisory employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.356
-- <table><tr><th>prod/non supervisory employee</th></tr><tr><td>1263650</td></tr></table>

-- %% [markdown]
-- 4. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, what is the average weekly hours worked by production and nonsupervisory employees across all industries? Answer : 36.06</span>

-- %%
SELECT ROUND(AVG(j.value), 2) AS 'Avg Wwekly Hours Pro/NS'
FROM LaborStatisticsDB.dbo.january_2017 as j
LEFT JOIN LaborStatisticsDB.dbo.series as s
ON j.series_id = s.series_id
WHERE series_title = 'average weekly hours of production and nonsupervisory employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.185
-- <table><tr><th>Avg Wwekly Hours Pro/NS</th></tr><tr><td>36.06</td></tr></table>

-- %% [markdown]
-- 5. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the total weekly payroll for production and nonsupervisory employees across all industries in January 2017? Round to the nearest penny, please. Answer : 1838753220</span>

-- %%
SELECT ROUND(SUM(j.value), 2) AS Total_Weekly_Payroll
FROM LaborStatisticsDB.dbo.january_2017 as j
LEFT JOIN LaborStatisticsDB.dbo.series as s
ON j.series_id = s.series_id
WHERE series_title = 'Aggregate weekly payrolls of production and nonsupervisory employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.138
-- <table><tr><th>Total_Weekly_Payroll</th></tr><tr><td>1838753220</td></tr></table>

-- %% [markdown]
-- 6. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, which industry was the average weekly hours worked by production and nonsupervisory employees the highest? Which industry was the lowest? <b>Highest : Motor vehicle power train components Lowest : Fitness and recreational sports centers</b></span>

-- %%
select  avg(j.value) 'average weekly hours by industry',i.industry_name 'industry name'
from LaborStatisticsDB.dbo.january_2017 as j 
join LaborStatisticsDB.dbo.series as s 
on  s.series_id= j.series_id
join LaborStatisticsDB.dbo.industry as i
on i.industry_code=s.industry_code
where s.data_type_code = 07
group by i.industry_name
order by 'average weekly hours by industry' DESC;
-- Out:
-- (501 rows affected)
-- Total execution time: 00:00:00.215
-- <table><tr><th>average weekly hours by industry</th><th>industry name</th></tr><tr><td>49.6</td><td>Motor vehicle power train components</td></tr><tr><td>47.2</td><td>Support activities for mining</td></tr><tr><td>46.7</td><td>Support activities for oil and gas operations</td></tr><tr><td>46.699999999999996</td><td>Motor vehicle metal stamping</td></tr><tr><td>46.6</td><td>Coal mining</td></tr><tr><td>46.1</td><td>Oil and gas pipeline construction</td></tr><tr><td>46.025</td><td>Mining</td></tr><tr><td>45.7</td><td>Boilers</td></tr><tr><td>45.7</td><td>Crushed and broken limestone mining</td></tr><tr><td>45.65</td><td>Mining and logging</td></tr><tr><td>45.55</td><td>Stone mining and quarrying</td></tr><tr><td>45.35</td><td>Petroleum and coal products</td></tr><tr><td>45.15
<span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2021, which industry was the total weekly payroll for production and nonsupervisory employees the highest? Which industry was the lowest? <b>Highest total weekly payroll : Total Private</b>, <b>Lowest total weekly payroll : Coin-operated laundries and drycleaners</b></span>

-- %%
SELECT i.industry_name, s.series_title, j.value
FROM LaborStatisticsDB.dbo.industry as i 
LEFT JOIN LaborStatisticsDB.dbo.series as s 
ON i.industry_code = s.industry_code
LEFT JOIN LaborStatisticsDB.dbo.january_2017 as j
ON s.series_id = j.series_id
WHERE series_title = 'Aggregate weekly payrolls of production and nonsupervisory employees'
AND i.industry_name is NOT NULL
ORDER BY j.value DESC
-- Out:
-- (2064 rows affected)
-- Total execution time: 00:00:00.416
-- <table><tr><th>industry_name</th><th>series_title</th><th>value</th></tr><tr><td>Total private</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>74498171</td></tr><tr><td>Total private</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>74498171</td></tr><tr><td>Total private</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>73474302</td></tr><tr><td>Total private</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>73474302</td></tr><tr><td>Private service-providing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60914722</td></tr><tr><td>Private service-providing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60914722</td></tr><tr><td>Private service-providing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60807771</td></tr><tr><td>Private service-providing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60807771</td></tr><tr><td>Professional and business services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>15251268</td></tr><tr><td>Professional and business services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>15251268</td></tr><tr><td>Professional and business services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>15219807</td></tr><tr><td>Professional and business services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>15219807</td></tr><tr><td>Trade</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14850661</td></tr><tr><td>Trade</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14850661</td></tr><tr><td>Education and health services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14816074</td></tr><tr><td>Education and health services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14816074</td></tr><tr><td>Education and health services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14765156</td></tr><tr><td>Education and health services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14765156</td></tr><tr><td>Trade</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14732108</td></tr><tr><td>Trade</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>14732108</td></tr><tr><td>Goods-producing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>13426820</td></tr><tr><td>Goods-producing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>13426820</td></tr><tr><td>Health care and social assistance</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12878462</td></tr><tr><td>Health care and social assistance</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12878462</td></tr><tr><td>Health care and social assistance</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12762526</td></tr><tr><td>Health care and social assistance</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12762526</td></tr><tr><td>Goods-producing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12711945</td></tr><tr><td>Goods-producing</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>12711945</td></tr><tr><td>Professional and technical services</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>8976687</td></tr><tr><td>Professional and tech ...

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Subqueries, Unions, Derived Tables, Oh My!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Write a query that returns the series_id, industry_code, industry_name, and value from the january_2017 table but only if that value is greater than the average value for annual_2016 of data_type_code 82.</span>

-- %%
select j.series_id,i.industry_code,i.industry_name ,j.value
from LaborStatisticsDB.dbo.january_2017 as j 
inner join LaborStatisticsDB.dbo.series as s
on s.series_id=j.series_id
inner join LaborStatisticsDB.dbo.industry as i 
on s.industry_code=i.industry_code
where data_type_code=82 and j.value > ( select avg(a.value) from LaborStatisticsDB.dbo.annual_2016 as a
where   series_id LIKE '%82' );
-- Out:
-- (294 rows affected)
-- Total execution time: 00:00:00.227
ing</td><td>7491723</td></tr><tr><td>CEU3000000082</td><td>30000000</td><td>Manufacturing</td><td>7411960</td></tr><tr><td>CES3100000082</td><td>31000000</td><td>Durable goods</td><td>4859716</td></tr><tr><td>CEU3100000082</td><td>31000000</td><td>Durable goods</td><td>4808368</td></tr><tr><td>CES3100000082</td><td>31000000</td><td>Durable goods</td><td>4859716</td></tr><tr><td>CEU3100000082</td><td>31000000</td><td>Durable goods</td><td>4808368</td></tr><tr><td>CES3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>871298</td></tr><tr><td>CEU3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>867242</td></tr><tr><td>CES3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>871298</td></tr><tr><td>CEU3133200082</td><td>31332000</td><td>Fabricated metal products</t ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Create a Union table comparing average weekly earnings&nbsp; of production and nonsupervisory employees between annual_16 and january_17 using the data type 30.&nbsp; Round to the nearest penny.&nbsp; You should have a column for the average earnings and a column for the year, and the period.</span>

-- %%
select round(a.value,0) 'average earnings' ,a.year,a.period from LaborStatisticsDB.dbo.annual_2016 as a 
join LaborStatisticsDB.dbo.series as s 
on a.series_id= s.series_id 
where s.data_type_code=30
union 
select round(j.value,0)'average earnings',j.year,j.period from LaborStatisticsDB.dbo.january_2017 as j
join LaborStatisticsDB.dbo.series as s 
on j.series_id=s.series_id
where s.data_type_code=30
-- order by [value],[year];
-- Out:
-- (1128 rows affected)
-- Total execution time: 00:00:00.196
-- <table><tr><th>average earnings</th><th>year</th><th>period</th></tr><tr><td>231</td><td>2016</td><td>M13</td></tr><tr><td>232</td><td>2017</td><td>M01</td></tr><tr><td>233</td><td>2016</td><td>M13</td></tr><tr><td>235</td><td>2017</td><td>M01</td></tr><tr><td>237</td><td>2017</td><td>M01</td></tr><tr><td>239</td><td>2017</td><td>M01</td></tr><tr><td>244</td><td>2016</td><td>M13</td></tr><tr><td>244</td><td>2017</td><td>M01</td></tr><tr><td>245</td><td>2017</td><td>M01</td></tr><tr><td>246</td><td>2016</td><td>M13</td></tr><tr><td>249</td><td>2017</td><td>M01</td></tr><tr><td>252</td><td>2017</td><td>M01</td></tr><tr><td>253</td><td>2017</td><td>M01</td></tr><tr><td>255</td><td>2016</td><td>M13</td></tr><tr><td>255</td><td>2017</td><td>M01</td></tr><tr><td>256</td><td>2016</td><td>M13</td></tr><tr><td>257</td><td>2016</td><td>M13</td></tr><tr><td>260</td><td>2017</td><td>M01</td></tr><tr><td>262</td><td>2016</td><td>M13</td></tr><tr><td>262</td><td>2017</td><td>M01</td></tr><tr><td>265</td><td>2017</td><td>M01</td></tr><tr><td>266</td><td>2016</td><td>M13</td></tr><tr><td>270</td><td>2017</td><td>M01</td></tr><tr><td>273</td><td>2017</td><td>M01</td></tr><tr><td>274</td><td>2017</td><td>M01</td></tr><tr><td>277</td><td>2016</td><td>M13</td></tr><tr><td>277</td><td>2017</td><td>M01</td
-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; vertical-align: baseline; white-space: pre-wrap;">Summarize Your Results</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); vertical-align: baseline; white-space: pre-wrap;">With what you know now about the </span>  <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 13.3333px; white-space: pre-wrap;">Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results and working with the</span> <span style="color: rgb(102, 102, 102); white-space: pre-wrap; font-family: &quot;Times New Roman&quot;; font-size: 13.3333px;">Labor Statistics Database</span><span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.</span>

-- %% [markdown]
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">During which time period did production and nonsupervisory employees fare better? Answer : </span> The employees did better in the January (MO1 period) 2017 as the average weekly earning was 1847. This was based on the data from the union table created above.

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In which industries did production and nonsupervisory employees fare better? </span>  Answer: Employees of production and non supervisory of "_<u>REINSURANCE CARRIERS</u>_" industry have been paid better fare.They have got average weekly earning of  <span style="box-sizing: unset; color: var(--vscode-foreground); background-color: rgb(255, 255, 255); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">1847dollars.</span>

-- %%
select round(a.value,0) 'average earnings' ,i.industry_name from LaborStatisticsDB.dbo.annual_2016 as a 
join LaborStatisticsDB.dbo.series as s 
on a.series_id= s.series_id 
join LaborStatisticsDB.dbo.industry as i
on i.industry_code=s.industry_code
where s.data_type_code=30
union 
select round(j.value,0)'average earnings',i.industry_name from LaborStatisticsDB.dbo.january_2017 as j
join LaborStatisticsDB.dbo.series as s 
on j.series_id=s.series_id
join LaborStatisticsDB.dbo.industry as i 
on i.industry_code=s.industry_code
where s.data_type_code=30
-- Out:
-- (1622 rows affected)
-- Total execution time: 00:00:00.517
-- <table><tr><th>average earnings</th><th>industry_name</th></tr><tr><td>231</td><td>Family clothing stores</td></tr><tr><td>232</td><td>Bowling centers</td></tr><tr><td>233</td><td>Bowling centers</td></tr><tr><td>235</td><td>Family clothing stores</td></tr><tr><td>237</td><td>Bowling centers</td></tr><tr><td>239</td><td>Women&#39;s clothing stores</td></tr><tr><td>244</td><td>Fitness and recreational sports centers</td></tr><tr><td>245</td><td>Fitness and recreational sports centers</td></tr><tr><td>246</td><td>Limited-service restaurants</td></tr><tr><td>249</td><td>Limited-service restaurants</td></tr><tr><td>252</td><td>Clothing stores</td></tr><tr><td>253</td><td>Family clothing stores</td></tr><tr><td>253</td><td>Women&#39;s clothing stores</td></tr><tr><td>255</td><td>Clothing stores</td></tr><tr><td>255</td><td>Limited-service restaurants</td></tr><tr><td>256</td><td>Snack and nonalcoholic beverage bars</td></tr><tr><td>257</td><td>Civic and social organizations</td></tr><tr><td>257</td><td>Clothing accessories stores</td></tr><tr><td>260</td><td>Snack and nonalcoholic be